# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('Mission.csv')

# %%
print(df)
# Out:
#    Mission_ID       Mission_Name       Agency       Country  Launch_Year  \
# 0       SM001      Chandrayaan-1         ISRO         India         2008
# 1       SM002      Chandrayaan-2         ISRO         India         2019
# 2       SM003         Mangalyaan         ISRO         India         2013
# 3       SM004          Aditya-L1         ISRO         India         2023
# 4       SM005            GSAT-11         ISRO         India         2018
# 5       SM006           INSAT-3D         ISRO         India         2013
# 6       SM007                NaN         ISRO         India         2011
# 7       SM008         Cartosat-2         ISRO         India         2007
# 8       SM009          Apollo 11         NASA           USA         1969
# 9       SM010          Apollo 13         NASA           USA         1970
# 10      SM011         James Webb         NASA           USA         2021
# 11      SM012          Artemis I         NASA           USA         2022
# ...

# %%
display(df)
# Out:
#    Mission_ID       Mission_Name       Agency       Country  Launch_Year  \
# 0       SM001      Chandrayaan-1         ISRO         India         2008
# 1       SM002      Chandrayaan-2         ISRO         India         2019
# 2       SM003         Mangalyaan         ISRO         India         2013
# 3       SM004          Aditya-L1         ISRO         India         2023
# 4       SM005            GSAT-11         ISRO         India         2018
# 5       SM006           INSAT-3D         ISRO         India         2013
# 6       SM007                NaN         ISRO         India         2011
# 7       SM008         Cartosat-2         ISRO         India         2007
# 8       SM009          Apollo 11         NASA           USA         1969
# 9       SM010          Apollo 13         NASA           USA         1970
# 10      SM011         James Webb         NASA           USA         2021
# 11      SM012          Artemis I         NASA           USA         2022
# ...

# %%
df.head(5)
# Out:
#   Mission_ID   Mission_Name Agency Country  Launch_Year  Launch_Site  \
# 0      SM001  Chandrayaan-1   ISRO   India         2008  Sriharikota
# 1      SM002  Chandrayaan-2   ISRO   India         2019  Sriharikota
# 2      SM003     Mangalyaan   ISRO   India         2013  Sriharikota
# 3      SM004      Aditya-L1   ISRO   India         2023  Sriharikota
# 4      SM005        GSAT-11   ISRO   India         2018       Kourou
#
#         Rocket Payload_kg   Mission_Type   Mission_Status  Mission_Cost_MUSD  \
# 0         PSLV       1380          Lunar          Success               83.0
# 1  GSLV Mk III       3850          Lunar  Partial Success              140.0
# 2         PSLV       1350   Mars Orbiter          Success               74.0
# 3         PSLV       1480          Solar          Success               46.0
# 4     Ariane 5       5854  Communication          Success              400.0
#
#           Orbit
# 0   Lunar Orbit
# 1   Trans Lunar
# 2  Heliocentric
# 3      L1 Orbit
# ...

# %%
df.tail(5)
# Out:
#    Mission_ID  Mission_Name   Agency Country  Launch_Year     Launch_Site  \
# 55      SM056  Iridium NEXT   SpaceX     USA         2019      Vandenberg
# 56      SM057           NaN   SpaceX     USA         2016  Cape Canaveral
# 57      SM058      OneWeb-1   OneWeb      UK         2019        Baikonur
# 58      SM059      OneWeb-2   OneWeb      UK         2020        Baikonur
# 59      SM060           NaN  Private     USA         2022  Cape Canaveral
#
#       Rocket Payload_kg   Mission_Type Mission_Status  Mission_Cost_MUSD Orbit
# 55  Falcon 9       9600  Communication        Success               70.0   LEO
# 56  Falcon 9        NaN           Test        Failure                NaN   LEO
# 57     Soyuz       6000      Satellite        Success              100.0   LEO
# 58     Soyuz       6000      Satellite        Failure              110.0   LEO
# 59  Falcon 9        NaN     Commercial        Success                NaN   LEO

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Mission_ID         60 non-null     object
#  1   Mission_Name       46 non-null     object
#  2   Agency             60 non-null     object
#  3   Country            60 non-null     object
#  4   Launch_Year        60 non-null     int64
#  5   Launch_Site        60 non-null     object
#  6   Rocket             60 non-null     object
#  7   Payload_kg         49 non-null     object
#  8   Mission_Type       60 non-null     object
#  9   Mission_Status     60 non-null     object
#  10  Mission_Cost_MUSD  48 non-null     float64
#  11  Orbit              59 non-null     object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 5.8+ KB

# %%
df["Payload_kg"] = pd.to_numeric(df["Payload_kg"], errors="coerce").astype(float)
df["Mission_Cost_MUSD"] = pd.to_numeric(df["Mission_Cost_MUSD"], errors="coerce").astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Mission_ID         60 non-null     object
#  1   Mission_Name       46 non-null     object
#  2   Agency             60 non-null     object
#  3   Country            60 non-null     object
#  4   Launch_Year        60 non-null     int64
#  5   Launch_Site        60 non-null     object
#  6   Rocket             60 non-null     object
#  7   Payload_kg         48 non-null     float64
#  8   Mission_Type       60 non-null     object
#  9   Mission_Status     60 non-null     object
#  10  Mission_Cost_MUSD  48 non-null     float64
#  11  Orbit              59 non-null     object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 5.8+ KB

# %%
df['Agency']
# Out:
# 0            ISRO
# 1            ISRO
# 2            ISRO
# 3            ISRO
# 4            ISRO
# 5            ISRO
# 6            ISRO
# 7            ISRO
# 8            NASA
# 9            NASA
# 10           NASA
# 11           NASA
# 12           NASA
# 13           NASA
# 14         SpaceX
# 15         SpaceX
# 16         SpaceX
# 17         SpaceX
# 18         SpaceX
# 19         SpaceX
# 20           CNSA
# 21           CNSA
# 22           CNSA
# 23           CNSA
# 24           CNSA
# 25      Roscosmos
# 26      Roscosmos
# 27      Roscosmos
# 28      Roscosmos
# 29      Roscosmos
# 30            ESA
# 31            ESA
# 32            ESA
# 33            ESA
# 34            ESA
# 35            ESA
# 36           JAXA
# 37           JAXA
# 38           JAXA
# 39           JAXA
# 40         SpaceX
# 41    Blue Origin
# 42    Blue Origin
# 43            ESA
# 44           ISRO
# 45           ISRO
# 46           ISRO
# 47           ISRO
# 48           NASA
# 49           NASA
# ...

# %%
print(df.isnull().sum())
# Out:
# Mission_ID            0
# Mission_Name         14
# Agency                0
# Country               0
# Launch_Year           0
# Launch_Site           0
# Rocket                0
# Payload_kg           12
# Mission_Type          0
# Mission_Status        0
# Mission_Cost_MUSD    12
# Orbit                 1
# dtype: int64

# %%
df.dtypes
# Out:
# Mission_ID            object
# Mission_Name          object
# Agency                object
# Country               object
# Launch_Year            int64
# Launch_Site           object
# Rocket                object
# Payload_kg           float64
# Mission_Type          object
# Mission_Status        object
# Mission_Cost_MUSD    float64
# Orbit                 object
# dtype: object

# %%
print(type(df['Payload_kg']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
pd.pivot_table(df,
               values="Mission_Cost_MUSD",
               index="Agency",
               columns="Mission_Status",
               aggfunc="mean")
# Out:
# Mission_Status      Failure  Partial Success      Success
# Agency
# Blue Origin             NaN              NaN    28.000000
# CNSA                    NaN              NaN  1425.000000
# ESA              180.000000           1400.0   805.000000
# ISRO                    NaN             82.5   161.000000
# JAXA                    NaN            300.0   225.000000
# NASA            1893.333333              NaN  2845.875000
# OneWeb           110.000000              NaN   100.000000
# Roscosmos        250.000000              NaN   140.000000
# SpaceX            60.000000              NaN    67.833333

# %% [markdown]
# numpy operaations

# %%
import numpy as np

data = df[["Launch_Year", "Payload_kg", "Mission_Cost_MUSD"]].to_numpy()

launch_year = data[:, 0]
payload = data[:, 1]
cost = data[:, 2]

# %%
np.nanmean(cost)
# Out:
# np.float64(888.2291666666666)

# %%
np.nanmin(cost)
# Out:
# np.float64(15.0)

# %%
np.nanmax(cost)
# Out:
# np.float64(10000.0)

# %%
np.nansum(payload)
# Out:
# np.float64(331000.0)

# %%
np.nanstd(payload)
# Out:
# np.float64(9141.607114664734)

# %%
np.nanstd(cost)
# Out:
# np.float64(1655.0438216703828)

# %%
data[cost > 1000]
# Out:
# array([[ 1969., 43000.,  3550.],
#        [ 1970., 43000.,  3500.],
#        [ 2021.,  6200., 10000.],
#        [ 2022., 26000.,  4000.],
#        [ 1990., 11110.,  2500.],
#        [ 2013.,  3780.,  1200.],
#        [ 2020.,  8200.,  1500.],
#        [ 2020.,  5000.,  2000.],
#        [ 2016.,  4300.,  1400.],
#        [ 2018.,  4100.,  2000.],
#        [ 2003., 11110.,  2000.]])

# %%
data[np.argsort(payload)]
# Out:
# array([[2.018e+03, 3.620e+02, 3.370e+02],
#        [2.010e+03, 5.000e+02, 3.000e+02],
#        [2.003e+03, 5.100e+02, 1.500e+02],
#        [2.014e+03, 6.090e+02, 3.000e+02],
#        [2.007e+03, 6.800e+02,       nan],
#        [2.019e+03, 7.400e+02, 2.500e+01],
#        [2.018e+03, 9.350e+02, 1.800e+02],
#        [1.999e+03, 9.500e+02, 1.800e+02],
#        [2.009e+03, 1.052e+03, 6.000e+02],
#        [2.017e+03, 1.200e+03,       nan],
#        [2.020e+03, 1.200e+03, 1.800e+02],
#        [2.013e+03, 1.350e+03, 7.400e+01],
#        [2.017e+03, 1.378e+03, 1.500e+01],
#        [2.008e+03, 1.380e+03, 8.300e+01],
#        [2.023e+03, 1.480e+03, 4.600e+01],
#        [2.021e+03, 1.550e+03, 9.800e+02],
#        [2.015e+03, 1.950e+03, 6.000e+01],
#        [2.013e+03, 2.030e+03, 7.400e+02],
#        [2.013e+03, 2.060e+03, 2.500e+02],
#        [2.016e+03, 2.110e+03, 8.000e+02],
#        [2.014e+03, 2.300e+03, 2.800e+02],
#        [2.013e+03, 3.780e+03, 1.200e+03],
# ...
